# %% [markdown]
# #Task2: Try Linear regression on same prediction data using Tensorflow

# %%
import numpy as np
import tensorflow as tf

# %%
inputs = np.array([[73, 67, 43], [91, 88, 64], [87, 134, 58], [102, 43, 37], [69, 96, 70],[73, 67, 43], [91, 88, 64], 
                   [87, 134, 58], [102, 43, 37], [69, 96, 70], [73, 67, 43], [91, 88, 64], [87, 134, 58], [102, 43, 37], 
                   [69, 96, 70]], dtype='float64')

targets = np.array([[56, 70], [81, 101], [119, 133], [22, 37], [103, 119],[56, 70], [81, 101], [119, 133], [22, 37], 
                    [103, 119],[56, 70], [81, 101], [119, 133], [22, 37], [103, 119]], dtype='float64')

# %%
inputs = tf.Variable(inputs)
targets = tf.Variable(targets)
print("targets :\n",targets)
# Out:
# targets :
#  <tf.Variable 'Variable:0' shape=(15, 2) dtype=float64, numpy=
# array([[ 56.,  70.],
#        [ 81., 101.],
#        [119., 133.],
#        [ 22.,  37.],
#        [103., 119.],
#        [ 56.,  70.],
#        [ 81., 101.],
#        [119., 133.],
#        [ 22.,  37.],
#        [103., 119.],
#        [ 56.,  70.],
#        [ 81., 101.],
#        [119., 133.],
#        [ 22.,  37.],
#        [103., 119.]])>

# %%
v = np.random.rand(3,2)
r = np.random.randn(2)
v = tf.Variable(v)
r = tf.Variable(r)

print(v)
print("\n",r)
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[0.80364278, 0.41020101],
#        [0.75321472, 0.65594496],
#        [0.65492789, 0.97234576]])>
#
#  <tf.Variable 'Variable:0' shape=(2,) dtype=float64, numpy=array([1.97691661, 0.50514887])>

# %%
def model(s):
    return s @ v + r

# %%
prediction = model(inputs)
print(prediction)
# Out:
# tf.Tensor(
# [[139.2701249  116.2090025 ]
#  [183.30668973 157.78672576]
#  [210.81042824 180.48531552]
#  [140.5690449  106.52807802]
#  [175.5818337  159.84393786]
#  [139.2701249  116.2090025 ]
#  [183.30668973 157.78672576]
#  [210.81042824 180.48531552]
#  [140.5690449  106.52807802]
#  [175.5818337  159.84393786]
#  [139.2701249  116.2090025 ]
#  [183.30668973 157.78672576]
#  [210.81042824 180.48531552]
#  [140.5690449  106.52807802]
#  [175.5818337  159.84393786]], shape=(15, 2), dtype=float64)

# %%
def mse(t1,t2):
    return tf.reduce_mean(tf.square(t1 - t2))
print(mse(prediction,targets))
# Out:
# tf.Tensor(5927.370840496429, shape=(), dtype=float64)

# %%
epochs = 40
for epoch_count in range(epochs):
    
    with tf.GradientTape(persistent=True) as t:
        current_loss = mse(targets, model(inputs))

    v1 = t.gradient(current_loss,v)
    r1 = t.gradient(current_loss,r)

    v.assign_sub(1e-4 * v1)
    r.assign_sub(1e-4 * r1)
        
    print(f" \n Epoch count: {epoch_count} \n Loss value: {current_loss.numpy()}")
# Out:
#
#  Epoch count: 0
#  Loss value: 5927.370840496429
#
#  Epoch count: 1
#  Loss value: 3817.3828738199168
#
#  Epoch count: 2
#  Loss value: 2484.11964766029
#
#  Epoch count: 3
#  Loss value: 1638.3971652046973
#
#  Epoch count: 4
#  Loss value: 1099.103804650493
#
#  Epoch count: 5
#  Loss value: 752.7620310189199
#
#  Epoch count: 6
#  Loss value: 528.2273672722663
#
#  Epoch count: 7
#  Loss value: 380.85754179772135
#
#  Epoch count: 8
#  Loss value: 282.6064628363154
#
#  Epoch count: 9
#  Loss value: 215.8250239281935
#
#  Epoch count: 10
#  Loss value: 169.38113631063894
#
#  Epoch count: 11
#  Loss value: 136.2308782779903
#
#  Epoch count: 12
#  Loss value: 111.89764865355538
#
#  Epoch count: 13
#  Loss value: 93.51953170739858
#
#  Epoch count: 14
#  Loss value: 79.25228002013574
#
#  Epoch count: 15
#  Loss value: 67.89489960368083
#
#  Epoch count: 16
#  Loss value: 58.65460736258544
#
#  Epoch count: 17
#  Loss value: 50.99907870140417
#
#  Epoch count: 18
#  Loss value: 44.563390677317884
#
#  Epoch count: 19
#  Loss value: 39.09125895277726
#
#  Epoch count: 20
#  Loss value: 34.39779591612348
#
#  Epoch count: 21
#  Loss value: 30.34579123155692
#
#  Epoch count: 22
#  Loss value: 26.830503618058426
#
#  Epoch count: 23
#  Loss value: 23.769822534619266
#
#  Epoch count: 24
#  Loss value: 21.097829014323853
#
#  Epoch count: 25
#  Loss value: 18.760517872555912
#
#  Epoch count: 26
#  Loss value: 16.71290266385456
#
#  Epoch count: 27
#  Loss value: 14.917012528708137
#
#  Epoch count: 28
#  Loss value: 13.340470557753237
#
#  Epoch count: 29
#  Loss value: 11.955456616249545
#
#  Epoch count: 30
#  Loss value: 10.737928815774932
#
#  Epoch count: 31
#  Loss value: 9.667022701040644
#
#  Epoch count: 32
#  Loss value: 8.724575569868536
#
#  Epoch count: 33
#  Loss value: 7.894741319448949
#
#  Epoch count: 34
#  Loss value: 7.16367266711204
#
#  Epoch count: 35
#  Loss value: 6.51925494434232
#
#  Epoch count: 36
#  Loss value: 5.950880422832859
#
#  Epoch count: 37
#  Loss value: 5.449255251053169
#
#  Epoch count: 38
#  Loss value: 5.006233155869003
#
#  Epoch count: 39
#  Loss value: 4.6146714716746216
